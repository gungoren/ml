# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

x = ["1. USD", "2. CHINA", "3. JAPANESE", "4. GERMANY", "5. ENGLAND", "6. FRANCE", "7. TURKEY"]
y = [20410, 14090, 5170, 4210, 2940, 2930, 3231]
z = [63039, 9957, 40649, 51158, 44162, 44915, 32332]

f = plt.figure(figsize=[10,6])

# %% [markdown]
# ### scatter

# %%
world = pd.read_csv("../../data/dünya.csv")
plt.scatter(world["Ülke"], world["Kişi Başına"])

# %% [markdown]
# ### histogram

# %%
plt.hist(world["Kişi Başına"])
# Out:
# (array([5., 2., 1., 2., 3., 3., 2., 1., 0., 1.]),
#  array([ 2104. , 10556.2, 19008.4, 27460.6, 35912.8, 44365. , 52817.2,
#         61269.4, 69721.6, 78173.8, 86626. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### step

# %%
plt.step(x,y)

# %% [markdown]
# ### piechart

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Turkey', 'USA', 'China', 'Germany'
sizes = [15, 35, 35, 15]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.206079876925476,
#  1.116979225356752,
#  -1.1476690042245155,
#  1.1022699525821198)
