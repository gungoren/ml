# %%
import pandas as pd

# %%
countries = pd.read_csv("../../data/dünya.csv")
countries.head(3)
# Out:
#       Ülke     Gelir     Nüfus  Kişi Başına           KITA
# 0      ABD  20410000   323,766        63039  Kuzey Amerika
# 1      Çin  14090000  1415,045         9957           Asya
# 2  Japonya   5170000   127,185        40649           Asya

# %%
countries[["Ülke", "KITA"]].head()
# Out:
#         Ülke           KITA
# 0        ABD  Kuzey Amerika
# 1        Çin           Asya
# 2    Japonya           Asya
# 3    Almanya         Avrupa
# 4  İngiltere         Avrupa

# %%
countries["Order"] = "Top 20"

# %%
countries.head()
# Out:
#         Ülke     Gelir     Nüfus  Kişi Başına           KITA   Order
# 0        ABD  20410000   323,766        63039  Kuzey Amerika  Top 20
# 1        Çin  14090000  1415,045         9957           Asya  Top 20
# 2    Japonya   5170000   127,185        40649           Asya  Top 20
# 3    Almanya   4210000    82,293        51158         Avrupa  Top 20
# 4  İngiltere   2940000    66,573        44162         Avrupa  Top 20

# %%
countries.insert(2, column="Income Level", value = "Very High")

# %%
countries
# Out:
#                Ülke     Gelir Income Level     Nüfus  Kişi Başına  \
# 0               ABD  20410000    Very High   323,766        63039
# 1               Çin  14090000    Very High  1415,045         9957
# 2           Japonya   5170000    Very High   127,185        40649
# 3           Almanya   4210000    Very High    82,293        51158
# 4         İngiltere   2940000    Very High    66,573        44162
# 5            Fransa   2930000    Very High    65,233        44915
# 6         Hindistan   2850000    Very High  1354,051         2104
# 7            İtalya   2180000    Very High     59,29        36768
# 8          Brezilya   2140000    Very High   210,867        10148
# 9            Kanada   1800000    Very High    36,953        48710
# 10            Rusya   1720000    Very High   143,967        11947
# 11       GÜney Kore   1690000    Very High    51,164        33031
# 12          İspanya   1510000    Very High    46,397        32545
# ...

# %%
countries["Gelir"] = countries["Gelir"] * 1000000
# Out:
#                Ülke   Gelir Income Level     Nüfus  Kişi Başına  \
# 0               ABD  20.410    Very High   323,766        63039
# 1               Çin  14.090    Very High  1415,045         9957
# 2           Japonya   5.170    Very High   127,185        40649
# 3           Almanya   4.210    Very High    82,293        51158
# 4         İngiltere   2.940    Very High    66,573        44162
# 5            Fransa   2.930    Very High    65,233        44915
# 6         Hindistan   2.850    Very High  1354,051         2104
# 7            İtalya   2.180    Very High     59,29        36768
# 8          Brezilya   2.140    Very High   210,867        10148
# 9            Kanada   1.800    Very High    36,953        48710
# 10            Rusya   1.720    Very High   143,967        11947
# 11       GÜney Kore   1.690    Very High    51,164        33031
# 12          İspanya   1.510    Very High    46,397        32545
# 13      Avusturalya   1.500    Very High    24,772        60552
# ...

# %%
countries
# Out:
#                Ülke   Gelir Income Level     Nüfus  Kişi Başına  \
# 0               ABD  20.410    Very High   323,766        63039
# 1               Çin  14.090    Very High  1415,045         9957
# 2           Japonya   5.170    Very High   127,185        40649
# 3           Almanya   4.210    Very High    82,293        51158
# 4         İngiltere   2.940    Very High    66,573        44162
# 5            Fransa   2.930    Very High    65,233        44915
# 6         Hindistan   2.850    Very High  1354,051         2104
# 7            İtalya   2.180    Very High     59,29        36768
# 8          Brezilya   2.140    Very High   210,867        10148
# 9            Kanada   1.800    Very High    36,953        48710
# 10            Rusya   1.720    Very High   143,967        11947
# 11       GÜney Kore   1.690    Very High    51,164        33031
# 12          İspanya   1.510    Very High    46,397        32545
# 13      Avusturalya   1.500    Very High    24,772        60552
# ...

# %%
countries["Incom TRY"] = countries["Gelir"] * 4.75

# %%
countries
# Out:
#                Ülke   Gelir Income Level     Nüfus  Kişi Başına  \
# 0               ABD  20.410    Very High   323,766        63039
# 1               Çin  14.090    Very High  1415,045         9957
# 2           Japonya   5.170    Very High   127,185        40649
# 3           Almanya   4.210    Very High    82,293        51158
# 4         İngiltere   2.940    Very High    66,573        44162
# 5            Fransa   2.930    Very High    65,233        44915
# 6         Hindistan   2.850    Very High  1354,051         2104
# 7            İtalya   2.180    Very High     59,29        36768
# 8          Brezilya   2.140    Very High   210,867        10148
# 9            Kanada   1.800    Very High    36,953        48710
# 10            Rusya   1.720    Very High   143,967        11947
# 11       GÜney Kore   1.690    Very High    51,164        33031
# 12          İspanya   1.510    Very High    46,397        32545
# 13      Avusturalya   1.500    Very High    24,772        60552
# ...

# %%
countries["KITA"].value_counts()
# Out:
# Avrupa           8
# Asya             7
# Kuzey Amerika    3
# Güney Amerika    1
# Okyanusya        1
# Name: KITA, dtype: int64
